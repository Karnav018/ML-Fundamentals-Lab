# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../prem/data/raw/raw_ecommerce_dataset.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Order_ID    Customer_Name                  Email      City  \
# 0           0      5275     Customer_275  user_275@provider.com  New York
# 1           1      5093    Customer_93     user_93@provider.com       NYC
# 2           2      5006       Customer_6    user_6@provider.com        NY
# 3           3      5167     Customer_167  user_167@provider.com   Chicago
# 4           4      5090      Customer_90   user_90@provider.com       NYC
#
#    Order_Date  Total_Spend
# 0   02-Aug-24       968.56
# 1   19-Aug-24       979.01
# 2  01/08/2024          NaN
# 3  2024-05-01      1139.36
# 4  10/09/2024       409.03

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     520 non-null    int64
#  1   Order_ID       520 non-null    int64
#  2   Customer_Name  520 non-null    str
#  3   Email          505 non-null    str
#  4   City           520 non-null    str
#  5   Order_Date     520 non-null    str
#  6   Total_Spend    490 non-null    float64
# dtypes: float64(1), int64(2), str(4)
# memory usage: 28.6 KB

# %%
df.drop(columns=['Unnamed: 0'] , inplace=True)

# %%
df.head()
# Out:
#    Order_ID    Customer_Name                  Email      City  Order_Date  \
# 0      5275     Customer_275  user_275@provider.com  New York   02-Aug-24
# 1      5093    Customer_93     user_93@provider.com       NYC   19-Aug-24
# 2      5006       Customer_6    user_6@provider.com        NY  01/08/2024
# 3      5167     Customer_167  user_167@provider.com   Chicago  2024-05-01
# 4      5090      Customer_90   user_90@provider.com       NYC  10/09/2024
#
#    Total_Spend
# 0       968.56
# 1       979.01
# 2          NaN
# 3      1139.36
# 4       409.03

# %%
df.shape
# Out:
# (520, 6)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_ID       520 non-null    int64
#  1   Customer_Name  520 non-null    str
#  2   Email          505 non-null    str
#  3   City           520 non-null    str
#  4   Order_Date     520 non-null    str
#  5   Total_Spend    490 non-null    float64
# dtypes: float64(1), int64(1), str(4)
# memory usage: 24.5 KB

# %%
df[df.duplicated()]
# Out:
#      Order_ID Customer_Name                  Email           City  Order_Date  \
# 43       5172  Customer_172  user_172@provider.com        Chicago  11/15/2024
# 134      5404  Customer_404  user_404@provider.com    los angeles  2024-10-02
# 182      5007    Customer_7    user_7@provider.com            CHI  2024-10-28
# 230      5234  Customer_234  user_234@provider.com            NYC   02-Sep-24
# 243      5131  Customer_131  user_131@provider.com    Los Angeles  2024-08-04
# 258      5374  Customer_374  user_374@provider.com    los angeles   28-Jun-24
# 283      5139  Customer_139  user_139@provider.com    Los Angeles  07/15/2024
# 291      5290  Customer_290  user_290@provider.com  new york city  02/15/2024
# 309      5057   Customer_57   user_57@provider.com            NYC  2024-05-27
# 350      5095   Customer_95   user_95@provider.com    los angeles  01/16/2024
# 374      5098   Customer_98   user_98@provider.com    Los Angeles   09-Jun-24
# ...

# %%
df.duplicated().shape
# Out:
# (520,)

# %%
df  = df.drop_duplicates()

# %%
df.head()
# Out:
#    Order_ID    Customer_Name                  Email      City  Order_Date  \
# 0      5275     Customer_275  user_275@provider.com  New York   02-Aug-24
# 1      5093    Customer_93     user_93@provider.com       NYC   19-Aug-24
# 2      5006       Customer_6    user_6@provider.com        NY  01/08/2024
# 3      5167     Customer_167  user_167@provider.com   Chicago  2024-05-01
# 4      5090      Customer_90   user_90@provider.com       NYC  10/09/2024
#
#    Total_Spend
# 0       968.56
# 1       979.01
# 2          NaN
# 3      1139.36
# 4       409.03

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 505 entries, 0 to 519
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_ID       505 non-null    int64
#  1   Customer_Name  505 non-null    str
#  2   Email          490 non-null    str
#  3   City           505 non-null    str
#  4   Order_Date     505 non-null    str
#  5   Total_Spend    475 non-null    float64
# dtypes: float64(1), int64(1), str(4)
# memory usage: 27.6 KB

# %%
df.head(10)
# Out:
#    Order_ID    Customer_Name                  Email      City  Order_Date  \
# 0      5275     Customer_275  user_275@provider.com  New York   02-Aug-24
# 1      5093    Customer_93     user_93@provider.com       NYC   19-Aug-24
# 2      5006       Customer_6    user_6@provider.com        NY  01/08/2024
# 3      5167     Customer_167  user_167@provider.com   Chicago  2024-05-01
# 4      5090      Customer_90   user_90@provider.com       NYC  10/09/2024
# 5      5007       Customer_7    user_7@provider.com       CHI  2024-10-28
# 6      5362     Customer_362  user_362@provider.com  New York   24-Feb-24
# 7      5228     Customer_228  user_228@provider.com  New York   11-May-24
# 8      5192     Customer_192  user_192@provider.com        LA  2024-12-16
# 9      5482     Customer_482                    NaN   chicago  03/07/2024
#
#    Total_Spend
# 0       968.56
# 1       979.01
# 2          NaN
# 3      1139.36
# 4       409.03
# 5       983.02
# 6       413.60
# 7       423.25
# ...

# %%
df[['Order_ID','Email']]
# Out:
#      Order_ID                  Email
# 0        5275  user_275@provider.com
# 1        5093   user_93@provider.com
# 2        5006    user_6@provider.com
# 3        5167  user_167@provider.com
# 4        5090   user_90@provider.com
# ..        ...                    ...
# 515      5071   user_71@provider.com
# 516      5106  user_106@provider.com
# 517      5270  user_270@provider.com
# 518      5435  user_435@provider.com
# 519      5102  user_102@provider.com
#
# [505 rows x 2 columns]

# %%
df['Email'].isnull().sum()
# Out:
# np.int64(15)

# %%
df['Last Three'] = df['Order_ID'] % 1000

# %%
df['Last Three'].head(10)
# Out:
# 0    275
# 1     93
# 2      6
# 3    167
# 4     90
# 5      7
# 6    362
# 7    228
# 8    192
# 9    482
# Name: Last Three, dtype: int64

# %%
df[['Order_ID','Last Three','Email']]
# Out:
#      Order_ID  Last Three                  Email
# 0        5275         275  user_275@provider.com
# 1        5093          93   user_93@provider.com
# 2        5006           6    user_6@provider.com
# 3        5167         167  user_167@provider.com
# 4        5090          90   user_90@provider.com
# ..        ...         ...                    ...
# 515      5071          71   user_71@provider.com
# 516      5106         106  user_106@provider.com
# 517      5270         270  user_270@provider.com
# 518      5435         435  user_435@provider.com
# 519      5102         102  user_102@provider.com
#
# [505 rows x 3 columns]

# %%
df['Email'] = df['Email'].fillna(df['Last Three'].apply(lambda x : f'user_{x}@provider.com'))

# %%
df['Email'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 505 entries, 0 to 519
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_ID       505 non-null    int64
#  1   Customer_Name  505 non-null    str
#  2   Email          505 non-null    str
#  3   City           505 non-null    str
#  4   Order_Date     505 non-null    str
#  5   Total_Spend    475 non-null    float64
#  6   Last Three     505 non-null    int64
# dtypes: float64(1), int64(2), str(4)
# memory usage: 31.6 KB

# %%
df['Total_Spend'].value_counts()
# Out:
# Total_Spend
# 34.25     2
# 210.12    2
# 770.45    2
# 968.56    1
# 979.01    1
#          ..
# 116.45    1
# 64.66     1
# 605.18    1
# 984.78    1
# 557.35    1
# Name: count, Length: 472, dtype: int64

# %%
df['Total_Spend'].describe()
# Out:
# count      475.000000
# mean       834.908547
# std       4572.258682
# min         21.140000
# 25%        354.180000
# 50%        638.380000
# 75%        927.410000
# max      99999.990000
# Name: Total_Spend, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.histplot(df['Total_Spend'], kde=True)
# Out:
# <Axes: xlabel='Total_Spend', ylabel='Count'>

# %%
sns.boxplot(x=df['Total_Spend'])
# Out:
# <Axes: xlabel='Total_Spend'>

# %%
plt.figure(figsize=(15,6))
sns.boxplot(data=df, x='Total_Spend', color='skyblue', showfliers=True)
plt.xlim(0, 2000)
plt.show()

# %%
df['Total_Spend'].describe()
# Out:
# count      475.000000
# mean       834.908547
# std       4572.258682
# min         21.140000
# 25%        354.180000
# 50%        638.380000
# 75%        927.410000
# max      99999.990000
# Name: Total_Spend, dtype: float64

# %%
df['Total_Spend'].mean()
# Out:
# np.float64(834.9085473684212)

# %%
df['Total_Spend'] = df['Total_Spend'].fillna(df['Total_Spend'].median())

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 505 entries, 0 to 519
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_ID       505 non-null    int64
#  1   Customer_Name  505 non-null    str
#  2   Email          505 non-null    str
#  3   City           505 non-null    str
#  4   Order_Date     505 non-null    str
#  5   Total_Spend    505 non-null    float64
#  6   Last Three     505 non-null    int64
# dtypes: float64(1), int64(2), str(4)
# memory usage: 31.6 KB

# %%
df.head(10)
# Out:
#    Order_ID    Customer_Name                  Email      City  Order_Date  \
# 0      5275     Customer_275  user_275@provider.com  New York   02-Aug-24
# 1      5093    Customer_93     user_93@provider.com       NYC   19-Aug-24
# 2      5006       Customer_6    user_6@provider.com        NY  01/08/2024
# 3      5167     Customer_167  user_167@provider.com   Chicago  2024-05-01
# 4      5090      Customer_90   user_90@provider.com       NYC  10/09/2024
# 5      5007       Customer_7    user_7@provider.com       CHI  2024-10-28
# 6      5362     Customer_362  user_362@provider.com  New York   24-Feb-24
# 7      5228     Customer_228  user_228@provider.com  New York   11-May-24
# 8      5192     Customer_192  user_192@provider.com        LA  2024-12-16
# 9      5482     Customer_482  user_482@provider.com   chicago  03/07/2024
#
#    Total_Spend  Last Three
# 0       968.56         275
# 1       979.01          93
# 2       638.38           6
# 3      1139.36         167
# ...

# %%
df['Order_Date'].head(12)
# Out:
# 0      02-Aug-24
# 1      19-Aug-24
# 2     01/08/2024
# 3     2024-05-01
# 4     10/09/2024
# 5     2024-10-28
# 6      24-Feb-24
# 7      11-May-24
# 8     2024-12-16
# 9     03/07/2024
# 10     11-Jan-24
# 11     27-Jul-24
# Name: Order_Date, dtype: str

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'] , format='mixed' , errors='coerce')

# %%
df['Order_Date'].head(12)
# Out:
# 0    2024-08-02
# 1    2024-08-19
# 2    2024-01-08
# 3    2024-05-01
# 4    2024-10-09
# 5    2024-10-28
# 6    2024-02-24
# 7    2024-05-11
# 8    2024-12-16
# 9    2024-03-07
# 10   2024-01-11
# 11   2024-07-27
# Name: Order_Date, dtype: datetime64[us]

# %%
df['Order_Day'] = df['Order_Date'].astype('str').str.split('-').str[2]
df['Order_Month'] = df['Order_Date'].astype('str').str.split('-').str[1]
df['Order_Year'] = df['Order_Date'].astype('str').str.split('-').str[0]

# %%
df.head(10)
# Out:
#    Order_ID    Customer_Name                  Email      City Order_Date  \
# 0      5275     Customer_275  user_275@provider.com  New York 2024-08-02
# 1      5093    Customer_93     user_93@provider.com       NYC 2024-08-19
# 2      5006       Customer_6    user_6@provider.com        NY 2024-01-08
# 3      5167     Customer_167  user_167@provider.com   Chicago 2024-05-01
# 4      5090      Customer_90   user_90@provider.com       NYC 2024-10-09
# 5      5007       Customer_7    user_7@provider.com       CHI 2024-10-28
# 6      5362     Customer_362  user_362@provider.com  New York 2024-02-24
# 7      5228     Customer_228  user_228@provider.com  New York 2024-05-11
# 8      5192     Customer_192  user_192@provider.com        LA 2024-12-16
# 9      5482     Customer_482  user_482@provider.com   chicago 2024-03-07
#
#    Total_Spend  Last Three Order_Day Order_Month Order_Year
# 0       968.56         275        02          08       2024
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 505 entries, 0 to 519
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_ID       505 non-null    int64
#  1   Customer_Name  505 non-null    str
#  2   Email          505 non-null    str
#  3   City           505 non-null    str
#  4   Order_Date     505 non-null    datetime64[us]
#  5   Total_Spend    505 non-null    float64
#  6   Last Three     505 non-null    int64
#  7   Order_Day      505 non-null    object
#  8   Order_Month    505 non-null    object
#  9   Order_Year     505 non-null    object
# dtypes: datetime64[us](1), float64(1), int64(2), object(3), str(3)
# memory usage: 59.6+ KB

# %%
df['Order_Day'] = df['Order_Day'].astype(int)
df['Order_Month'] = df['Order_Month'].astype(int)
df['Order_Year'] = df['Order_Year'].astype(int)

# %%
df.drop(columns=['Last Three'],inplace=True)

# %%
df['City'].head(10)
# Out:
# 0    New York
# 1         NYC
# 2          NY
# 3     Chicago
# 4         NYC
# 5         CHI
# 6    New York
# 7    New York
# 8          LA
# 9     chicago
# Name: City, dtype: str

# %%
df['City'].value_counts()
# Out:
# City
# NYC              62
# NY               60
# CHI              58
# Los Angeles      53
# los angeles      51
# New York         49
# LA               46
# new york city    45
# chicago          44
# Chicago          37
# Name: count, dtype: int64

# %%
df['City'] = df['City'].str.lower().str.strip()

# %%
df['City'].value_counts()
# Out:
# City
# los angeles      104
# chicago           81
# nyc               62
# ny                60
# chi               58
# new york          49
# la                46
# new york city     45
# Name: count, dtype: int64

# %%
city_mapping = {
    'nyc' : 'new york',
    'ny' : 'new york',
    'new york city' : 'new york',
    'chi' : 'chicago',
    'la' : 'los angeles'
}

# %%
df['City'] = df['City'].replace(city_mapping)

# %%
df['City'] = df['City'].str.title()

# %%
df['City'].head(13)
# Out:
# 0        New York
# 1        New York
# 2        New York
# 3         Chicago
# 4        New York
# 5         Chicago
# 6        New York
# 7        New York
# 8     Los Angeles
# 9         Chicago
# 10        Chicago
# 11        Chicago
# 12        Chicago
# Name: City, dtype: str

# %%
df.head(13)
# Out:
#     Order_ID    Customer_Name                  Email         City Order_Date  \
# 0       5275     Customer_275  user_275@provider.com     New York 2024-08-02
# 1       5093    Customer_93     user_93@provider.com     New York 2024-08-19
# 2       5006       Customer_6    user_6@provider.com     New York 2024-01-08
# 3       5167     Customer_167  user_167@provider.com      Chicago 2024-05-01
# 4       5090      Customer_90   user_90@provider.com     New York 2024-10-09
# 5       5007       Customer_7    user_7@provider.com      Chicago 2024-10-28
# 6       5362     Customer_362  user_362@provider.com     New York 2024-02-24
# 7       5228     Customer_228  user_228@provider.com     New York 2024-05-11
# 8       5192     Customer_192  user_192@provider.com  Los Angeles 2024-12-16
# 9       5482     Customer_482  user_482@provider.com      Chicago 2024-03-07
# 10      5218     Customer_218  user_218@provider.com      Chicago 2024-01-11
# ...

# %%
df[df.duplicated()]
# Out:
#      Order_ID Customer_Name                 Email      City Order_Date  \
# 222      5083   Customer_83  user_83@provider.com  New York 2024-08-04
#
#      Total_Spend  Order_Day  Order_Month  Order_Year
# 222        34.25          4            8        2024

# %%
df = df.drop_duplicates()

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Customer_Name, Email, City, Order_Date, Total_Spend, Order_Day, Order_Month, Order_Year]
# Index: []

# %%
df.duplicated().value_counts()
# Out:
# False    504
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 504 entries, 0 to 519
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_ID       504 non-null    int64
#  1   Customer_Name  504 non-null    str
#  2   Email          504 non-null    str
#  3   City           504 non-null    str
#  4   Order_Date     504 non-null    datetime64[us]
#  5   Total_Spend    504 non-null    float64
#  6   Order_Day      504 non-null    int64
#  7   Order_Month    504 non-null    int64
#  8   Order_Year     504 non-null    int64
# dtypes: datetime64[us](1), float64(1), int64(4), str(3)
# memory usage: 39.4 KB

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_Name', 'Email', 'City', 'Order_Date',
#        'Total_Spend', 'Order_Day', 'Order_Month', 'Order_Year'],
#       dtype='str')

# %%
df.rename(columns={'Order_ID' : 'Order_Id'},inplace=True)

# %%
df.columns
# Out:
# Index(['Order_Id', 'Customer_Name', 'Email', 'City', 'Order_Date',
#        'Total_Spend', 'Order_Day', 'Order_Month', 'Order_Year'],
#       dtype='str')

# %%
df.to_csv('ecommerce_cleaned.csv')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 504 entries, 0 to 519
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_Id       504 non-null    int64
#  1   Customer_Name  504 non-null    str
#  2   Email          504 non-null    str
#  3   City           504 non-null    str
#  4   Order_Date     504 non-null    datetime64[us]
#  5   Total_Spend    504 non-null    float64
#  6   Order_Day      504 non-null    int64
#  7   Order_Month    504 non-null    int64
#  8   Order_Year     504 non-null    int64
# dtypes: datetime64[us](1), float64(1), int64(4), str(3)
# memory usage: 39.4 KB

# %%
df.Order_Year.value_counts()
# Out:
# Order_Year
# 2024    503
# 2035      1
# Name: count, dtype: int64

# %%
df.loc[df['Order_Year'] > 2024, 'Order_Year'] = 2024

# %%
df.Order_Year.value_counts()
# Out:
# Order_Year
# 2024    504
# Name: count, dtype: int64

# %%
df['Customer_Name'] = df['Customer_Name'].str.strip()

# %%
df = df[df['Total_Spend'] < 2000]

# %%
df.describe()
# Out:
#           Order_Id                  Order_Date  Total_Spend   Order_Day  \
# count   503.000000                         503   503.000000  503.000000
# mean   5250.174950  2024-07-13 04:52:00.477137   627.631650   14.765408
# min    5000.000000         2024-01-02 00:00:00    21.140000    1.000000
# 25%    5126.500000         2024-04-05 12:00:00   365.095000    8.000000
# 50%    5250.000000         2024-07-08 00:00:00   638.380000   15.000000
# 75%    5374.500000         2024-10-13 12:00:00   889.030000   22.000000
# max    5499.000000         2035-01-01 00:00:00  1199.520000   28.000000
# std     143.877345                         NaN   329.263223    8.177113
#
#        Order_Month  Order_Year
# count   503.000000       503.0
# mean      6.667992      2024.0
# min       1.000000      2024.0
# 25%       4.000000      2024.0
# 50%       7.000000      2024.0
# 75%      10.000000      2024.0
# max      12.000000      2024.0
# std       3.470294         0.0

# %%
df['Customer_Name'].unique()
# Out:
# <StringArray>
# ['Customer_275',  'Customer_93',   'Customer_6', 'Customer_167',
#   'Customer_90',   'Customer_7', 'Customer_362', 'Customer_228',
#  'Customer_192', 'Customer_482',
#  ...
#  'Customer_330', 'Customer_214', 'Customer_466', 'Customer_121',
#   'Customer_20',  'Customer_71', 'Customer_106', 'Customer_270',
#  'Customer_435', 'Customer_102']
# Length: 499, dtype: str

# %%
df.to_csv('data/cleaned/ecommerce_cleaned.csv')
