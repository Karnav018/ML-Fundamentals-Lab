# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./data/raw/airbnb_nyc_raw_dataset.csv')
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  str
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  str
#  4   neighbourhood_group             48895 non-null  str
#  5   neighbourhood                   48895 non-null  str
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  str
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df['name'].unique()
# Out:
# <StringArray>
# [                'Clean & quiet apt home by the park',
#                               'Skylit Midtown Castle',
#                 'THE VILLAGE OF HARLEM....NEW YORK !',
#                     'Cozy Entire Floor of Brownstone',
#    'Entire Apt: Spacious Studio/Loft by central park',
#           'Large Cozy 1 BR Apartment In Midtown East',
#                                     'BlissArtsSpace!',
#                    'Large Furnished Room Near B'way ',
#                  'Cozy Clean Guest Room - Family Apt',
#                  'Cute & Cozy Lower East Side 1 bdrm',
#  ...
#     'Stunning Bedroom NYC! Walking to Central Park!!',
#                     'Comfy 1 Bedroom in Midtown East',
#     'Garden Jewel Apartment in Williamsburg New York',
#  'Spacious Room w/ Private Rooftop, Central location',
#                                  'QUIT PRIVATE HOUSE',
#     'Charming one bedroom - newly renovated rowhouse',
#       'Affordable room in Bushwick/East Williamsburg',
# ...

# %%
df.shape
# Out:
# (48895, 16)

# %%
df.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df['name'] = df['name'].fillna("Unknown")
df['host_name'] = df['host_name'].fillna("Unknown")

# %%
df[['name','host_name']].isna().sum()
# Out:
# name         0
# host_name    0
# dtype: int64

# %%
df[df['name'] == "Unknown"]
# Out:
#              id     name   host_id host_name neighbourhood_group  \
# 2854    1615764  Unknown   6676776     Peter           Manhattan
# 3703    2232600  Unknown  11395220      Anna           Manhattan
# 5775    4209595  Unknown  20700823     Jesse           Manhattan
# 5975    4370230  Unknown  22686810   Michaël           Manhattan
# 6269    4581788  Unknown  21600904     Lucie            Brooklyn
# 6567    4756856  Unknown   1832442  Carolina            Brooklyn
# 6605    4774658  Unknown  24625694      Josh           Manhattan
# 8841    6782407  Unknown  31147528  Huei-Yin            Brooklyn
# 11963   9325951  Unknown  33377685  Jonathan           Manhattan
# 12824   9787590  Unknown  50448556    Miguel           Manhattan
# 13059   9885866  Unknown  37306329  Juliette           Manhattan
# 13401  10052289  Unknown  49522403   Vanessa            Brooklyn
# 15819  12797684  Unknown  69715276       Yan           Manhattan
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48895 non-null  str
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48895 non-null  str
#  4   neighbourhood_group             48895 non-null  str
#  5   neighbourhood                   48895 non-null  str
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  str
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df.isna().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[['number_of_reviews', 'last_review', 'reviews_per_month']].isnull().corr()
# Out:
#                    number_of_reviews  last_review  reviews_per_month
# number_of_reviews                NaN          NaN                NaN
# last_review                      NaN          1.0                1.0
# reviews_per_month                NaN          1.0                1.0

# %% [markdown]
# It tells that its not MCAR(Missing Completely at ramdom)

# %%
df['reviews_per_month'] = df['reviews_per_month'].fillna(0)

# %%
df['reviews_per_month'].value_counts()
# Out:
# reviews_per_month
# 0.00     10052
# 0.02       919
# 0.05       893
# 1.00       893
# 0.03       804
#          ...
# 7.86         1
# 11.71        1
# 9.73         1
# 10.91        1
# 10.54        1
# Name: count, Length: 938, dtype: int64

# %%
df['reviews_per_month'].describe()
# Out:
# count    48895.000000
# mean         1.090910
# std          1.597283
# min          0.000000
# 25%          0.040000
# 50%          0.370000
# 75%          1.580000
# max         58.500000
# Name: reviews_per_month, dtype: float64

# %%
plt.figure(figsize=(15,10))
sns.histplot(x=df['reviews_per_month'] , kde=True)
plt.xlim(0,2)
plt.title("Reviews per month")
plt.show()

# %%
df['last_review'] = pd.to_datetime(df['last_review'], errors='coerce')

# %%
df['last_review'].head(15)
# Out:
# 0    2018-10-19
# 1    2019-05-21
# 2           NaT
# 3    2019-07-05
# 4    2018-11-19
# 5    2019-06-22
# 6    2017-10-05
# 7    2019-06-24
# 8    2017-07-21
# 9    2019-06-09
# 10   2019-06-22
# 11   2019-06-23
# 12   2019-06-24
# 13   2019-07-05
# 14   2018-10-31
# Name: last_review, dtype: datetime64[us]

# %%
df['price'].describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
df[df['price'] == 0].head(10)
# Out:
#              id                                               name    host_id  \
# 23161  18750597  Huge Brooklyn Brownstone Living, Close to it all.    8993084
# 25433  20333471      ★Hostel Style Room | Ideal Traveling Buddies★  131697576
# 25634  20523843    MARTIAL LOFT 3: REDEMPTION (upstairs, 2nd room)   15787004
# 25753  20608117                    Sunny, Quiet Room in Greenpoint    1641537
# 25778  20624541      Modern apartment in the heart of Williamsburg   10132166
# 25794  20639628  Spacious comfortable master bedroom with nice ...   86327101
# 25795  20639792  Contemporary bedroom in brownstone with nice view   86327101
# 25796  20639914       Cozy yet spacious private brownstone bedroom   86327101
# 26259  20933849                              the best you can find   13709292
# 26841  21291569  Coliving in Brooklyn! Modern design / Shared room  101970559
#
#           host_name neighbourhood_group       neighbourhood  latitude  \
# ...

# %% [markdown]
# Here price cannot be 0 for any listing

# %%
df['price'] = df['price'].replace(0, np.nan)

# %%
df[(df['price'] > 175) & (df['price'] < 10000)].shape
# Out:
# (12174, 16)

# %%
df['price'] = df.groupby(
    ['neighbourhood_group', 'room_type']
)['price'].transform(lambda x: x.fillna(x.median()))

# %%
df['price'].describe()
# Out:
# count    48895.000000
# mean       152.738112
# std        240.146850
# min         10.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
df['minimum_nights'].describe()
# Out:
# count    48895.000000
# mean         7.029962
# std         20.510550
# min          1.000000
# 25%          1.000000
# 50%          3.000000
# 75%          5.000000
# max       1250.000000
# Name: minimum_nights, dtype: float64

# %%
df[df['minimum_nights'] == 1250.0]
# Out:
#            id                              name   host_id  host_name  \
# 5767  4204302  Prime W. Village location 1 bdrm  17550546  Genevieve
#
#      neighbourhood_group      neighbourhood  latitude  longitude  \
# 5767           Manhattan  Greenwich Village  40.73293  -73.99782
#
#             room_type  price  minimum_nights  number_of_reviews last_review  \
# 5767  Entire home/apt  180.0            1250                  2  2014-11-09
#
#       reviews_per_month  calculated_host_listings_count  availability_365
# 5767               0.03                               1               365

# %%
cap = df['minimum_nights'].quantile(0.99)
df['minimum_nights_cleaned'] = df['minimum_nights'].clip(upper=cap)

# %%
df['availability_365'].describe()
# Out:
# count    48895.000000
# mean       112.781327
# std        131.622289
# min          0.000000
# 25%          0.000000
# 50%         45.000000
# 75%        227.000000
# max        365.000000
# Name: availability_365, dtype: float64

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48895 non-null  str
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48895 non-null  str
#  4   neighbourhood_group             48895 non-null  str
#  5   neighbourhood                   48895 non-null  str
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  str
#  9   price                           48895 non-null  float64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# minimum_nights_cleaned                0
# dtype: int64

# %%
df.describe(include='all')
# Out:
#                   id            name       host_id host_name  \
# count   4.889500e+04           48895  4.889500e+04     48895
# unique           NaN           47906           NaN     11453
# top              NaN  Hillside Hotel           NaN   Michael
# freq             NaN              18           NaN       417
# mean    1.901714e+07             NaN  6.762001e+07       NaN
# min     2.539000e+03             NaN  2.438000e+03       NaN
# 25%     9.471945e+06             NaN  7.822033e+06       NaN
# 50%     1.967728e+07             NaN  3.079382e+07       NaN
# 75%     2.915218e+07             NaN  1.074344e+08       NaN
# max     3.648724e+07             NaN  2.743213e+08       NaN
# std     1.098311e+07             NaN  7.861097e+07       NaN
#
#        neighbourhood_group neighbourhood      latitude     longitude  \
# count                48895         48895  48895.000000  48895.000000
# unique                   5           221           NaN           NaN
# ...

# %%
df.to_csv('data/cleaned/airbnb_nyc_cleaned_dataset.csv')
